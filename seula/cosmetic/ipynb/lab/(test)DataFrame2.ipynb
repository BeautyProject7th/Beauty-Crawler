# %%
import pandas as pd

# %%
df1 = pd.read_csv("skinfood_productList.csv", encoding="utf-8")

# %%
df1
# Out:
#          title    div    cate  \
# 0     SKINCARE    유형별     클렌징
# 1     SKINCARE    유형별     클렌징
# 2     SKINCARE    유형별     클렌징
# 3     SKINCARE    유형별     클렌징
# 4     SKINCARE    유형별     클렌징
# 5     SKINCARE    유형별     클렌징
# 6     SKINCARE    유형별     클렌징
# 7     SKINCARE    유형별     클렌징
# 8     SKINCARE    유형별     클렌징
# 9     SKINCARE    유형별     클렌징
# 10    SKINCARE    유형별     클렌징
# 11    SKINCARE    유형별     클렌징
# 12    SKINCARE    유형별     클렌징
# 13    SKINCARE    유형별     클렌징
# 14    SKINCARE    유형별     클렌징
# 15    SKINCARE    유형별     클렌징
# 16    SKINCARE    유형별     클렌징
# 17    SKINCARE    유형별     클렌징
# 18    SKINCARE    유형별     클렌징
# 19    SKINCARE    유형별     클렌징
# 20    SKINCARE    유형별     클렌징
# 21    SKINCARE    유형별     클렌징
# 22    SKINCARE    유형별     클렌징
# 23    SKINCARE    유형별     클렌징
# 24    SKINCARE    유형별     클렌징
# 25    SKINCARE    유형별     클렌징
# 26    SKINCARE    유형별     클렌징
# 27    SKINCARE    유형별     클렌징
# 28    SKINCARE    유형별     클렌징
# 29    SKINCARE    유형별     클렌징
# ...

# %%
cnt = len(df1)

# %%
for i in range(cnt):
    if df["div"]

# %%
pdlist = []
for i in range(cnt):
    if "유형별" in df1["div"][i]:
        category = df1["cate"][i]
        sub_cate = df1["sub_cate"][i]
        pdName = df1["pdName"][i]
        pdImg = df1["pdImg"][i]
        pdImg = "https://" + pdImg
        final = [category, sub_cate, pdName, pdImg]
        pdlist.append(final)

# %%
name = ["cate", "sub_cate", "pdName", "pdImg"]

# %%
df2 = pd.DataFrame(pdlist, columns=name)

# %%
df2
# Out:
#          cate   sub_cate                                pdName  \
# 0         클렌징      클렌징 폼                    에그 화이트 퍼펙트 포어 머랭 폼
# 1         클렌징      클렌징 폼                   에그 화이트 퍼펙트 포어 클렌징 폼
# 2         클렌징      클렌징 폼                            허니 밀 클렌징 폼
# 3         클렌징      클렌징 폼                    블랙슈가 퍼펙트 오일 클렌징 티슈
# 4         클렌징      클렌징 폼                          블랙슈가 퍼펙트 버블폼
# 5         클렌징      클렌징 폼                         비터 그린 클레이 투 폼
# 6         클렌징      클렌징 폼                          티트리 소프트 버블 폼
# 7         클렌징      클렌징 폼                             티트리 클렌징 폼
# 8         클렌징      클렌징 폼                        블랙슈가 퍼펙트 스크럽 폼
# 9         클렌징      클렌징 폼                렛츠 무스 치즈  클렌징 폼 JUMBO
# 10        클렌징      클렌징 폼                 렛츠 밀키 밀크  클렌징 폼 JUMBO
# 11        클렌징      클렌징 폼               렛츠 프레시 요거트  클렌징 폼 JUMBO
# 12        클렌징      클렌징 폼                       렛츠 밀키 밀크 버블 클렌저
# 13        클렌징      클렌징 폼                              렛츠 클렌징 폼
# ...

# %%
len(df2)
# Out:
# 532

# %%
df2.to_csv("skinfood.csv", encoding="utf-8")

# %%
import pandas as pd

# %%
df = pd.read_csv("skinfood_final.csv", encoding="utf-8")

# %%
df
# Out:
#           cate  sub_cate                                pdName  \
# 0     SKINCARE       클렌징                    에그 화이트 퍼펙트 포어 머랭 폼
# 1     SKINCARE       클렌징                   에그 화이트 퍼펙트 포어 클렌징 폼
# 2     SKINCARE       클렌징                            허니 밀 클렌징 폼
# 3     SKINCARE       클렌징                    블랙슈가 퍼펙트 오일 클렌징 티슈
# 4     SKINCARE       클렌징                          블랙슈가 퍼펙트 버블폼
# 5     SKINCARE       클렌징                         비터 그린 클레이 투 폼
# 6     SKINCARE       클렌징                          티트리 소프트 버블 폼
# 7     SKINCARE       클렌징                             티트리 클렌징 폼
# 8     SKINCARE       클렌징                        블랙슈가 퍼펙트 스크럽 폼
# 9     SKINCARE       클렌징                렛츠 무스 치즈  클렌징 폼 JUMBO
# 10    SKINCARE       클렌징                 렛츠 밀키 밀크  클렌징 폼 JUMBO
# 11    SKINCARE       클렌징               렛츠 프레시 요거트  클렌징 폼 JUMBO
# 12    SKINCARE       클렌징                       렛츠 밀키 밀크 버블 클렌저
# 13    SKINCARE       클렌징                              렛츠 클렌징 폼
# ...

# %%
hi = len(df)

# %%
for i in range(hi):
    if "·" in df["cate"][i]:
        df["cate"][i] = df["cate"][i].replace("·", "/")

# %%
df
# Out:
#           cate  sub_cate                                pdName  \
# 0     SKINCARE       클렌징                    에그 화이트 퍼펙트 포어 머랭 폼
# 1     SKINCARE       클렌징                   에그 화이트 퍼펙트 포어 클렌징 폼
# 2     SKINCARE       클렌징                            허니 밀 클렌징 폼
# 3     SKINCARE       클렌징                    블랙슈가 퍼펙트 오일 클렌징 티슈
# 4     SKINCARE       클렌징                          블랙슈가 퍼펙트 버블폼
# 5     SKINCARE       클렌징                         비터 그린 클레이 투 폼
# 6     SKINCARE       클렌징                          티트리 소프트 버블 폼
# 7     SKINCARE       클렌징                             티트리 클렌징 폼
# 8     SKINCARE       클렌징                        블랙슈가 퍼펙트 스크럽 폼
# 9     SKINCARE       클렌징                렛츠 무스 치즈  클렌징 폼 JUMBO
# 10    SKINCARE       클렌징                 렛츠 밀키 밀크  클렌징 폼 JUMBO
# 11    SKINCARE       클렌징               렛츠 프레시 요거트  클렌징 폼 JUMBO
# 12    SKINCARE       클렌징                       렛츠 밀키 밀크 버블 클렌저
# 13    SKINCARE       클렌징                              렛츠 클렌징 폼
# ...

# %%
df.to_csv("skinfood.csv", encoding="utf-8", index=False)
