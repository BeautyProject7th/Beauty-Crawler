# %%
import numpy as np
import pandas as pd
import requests
from bs4 import BeautifulSoup
from selenium import webdriver
from slacker import Slacker
from time import sleep
from selenium.webdriver.common.keys import Keys

# %%
token = 'xoxb-141438920821-DH6BthlLsHmJt306FV8ELkl6'
slack = Slacker(token)

# %%
url = "http://www.theskinfood.com/"

# %%
cate2 = category(["cate", "sub_cate", ""])

# %%
category = pd.read_csv("skinfood_SubCategory.csv", encoding="utf-8", keep_default_na=False)

# %%
category.to_csv("category_test.csv", encoding="utf-8", index=False)

# %%
cateNum = len(category)
cateNum
# Out:
# 146

# %%
category
# Out:
#          title    div         cate  \
# 0     SKINCARE    유형별          클렌징
# 1     SKINCARE    유형별          클렌징
# 2     SKINCARE    유형별          클렌징
# 3     SKINCARE    유형별          클렌징
# 4     SKINCARE    유형별          클렌징
# 5     SKINCARE    유형별          클렌징
# 6     SKINCARE    유형별          클렌징
# 7     SKINCARE    유형별        팩/마스크
# 8     SKINCARE    유형별        팩/마스크
# 9     SKINCARE    유형별        팩/마스크
# 10    SKINCARE    유형별        팩/마스크
# 11    SKINCARE    유형별        팩/마스크
# 12    SKINCARE    유형별           토너
# 13    SKINCARE    유형별         아이케어
# 14    SKINCARE    유형별       에센스/세럼
# 15    SKINCARE    유형별       에센스/세럼
# 16    SKINCARE    유형별       에센스/세럼
# 17    SKINCARE    유형별         오일/밤
# 18    SKINCARE    유형별         오일/밤
# 19    SKINCARE    유형별          에멀전
# 20    SKINCARE    유형별          에멀전
# 21    SKINCARE    유형별           크림
# 22    SKINCARE    유형별          선케어
# 23    SKINCARE    유형별          미스트
# 24    SKINCARE    유형별         세트상품
# ...

# %%
pdList = []

for i in range(cateNum):
    title = category["title"][i]
    div = category["div"][i]
    cate = category["cate"][i]
    cate_link = "/"+category["cate_link"][i]
    cate_flag = str(category["cate_flag"][i])
    
    message = "["+str(i)+"]"+title+","+div+","+cate
    slack.chat.post_message('#crawling', message)
    
    search = url+category["cate_link"][i] 
    driver = webdriver.Firefox() #brew install geckodriver
    driver.get(search)
    
    html = driver.page_source
    main_page = BeautifulSoup(html)
    #print(main_page) #한번 출력됨!

    #js 한번 실행. 그래야 상품 목록을 긁어 올 수 있다.
    if category["div"][i] != "푸드라인업":
        driver.execute_script("selectGoodsList('','','');") 
    #print(main_page) #한번 출력됨!
    sleep(5)
    
    #만약 SubCategory가 있다면
    if category["sub_id"][i] != 0:
        sub_cate = category["sub_cate"][i]
        sub_id = category["sub_id"][i]

        #subcategory로 이동하는 javascript를 실행
        sub_num = str(int(category["sub_id"][i]))
        move_sub = "selectGoodsList("+sub_num+");"
        driver.execute_script(move_sub)
        
        #subcategory의 기본 페이지 상품 가져오기
        sleep(5)
        html = driver.page_source
        sub_page = BeautifulSoup(html)
        #print(sub_page) #얘도 한번인데....
        
        #subcategory의 상품개수 가져오기
        resultCnt = sub_page.find_all("span", {"id" : "resultCount"})
        for cnt in resultCnt:
            resultCnt = cnt.text
        resultCnt = int(resultCnt)
        #print(sub_page) 얘도 한번!
        
        #more javascript를 실행 할 것인가?
        add_more = resultCnt - 25 #기본 개수 빼기
        mok = 0
        nam = 0
        if add_more>0:
            mok = int(add_more/10) + 1
            nam = (add_more%10)
            if nam != 0:
                mok += 1
        #print(sub_page) #한번
                
        #more javascript를 실행해야 한다면
        if mok!=0:
            for i in range(mok):
                driver.execute_script("selectGoodsList('','',10);")
            html = driver.page_source
            sub_page2 = BeautifulSoup(html)
        #print(sub_page) #연관 없음
            
        #상품 목록 정리하기
        pdhtml= str(sub_page.find("ul", {"id" : "tbodyList"}))
        pdhtml = pdhtml.replace("><", ">\n<")
        pdhtml = pdhtml.replace("[", "\n")
        pdhtml = pdhtml.replace("]", "")
        pdhtml = pdhtml.split("\n")
        #print(pdhtml) #한번 출력

        img_pd = []
        imgSrc = ""
        pdPage = ""
        pdName = ""
        num = 0
            
        for line in pdhtml:
            if "<a href=" in line:
                pdPage = line[9:-2]
            if "<img src=" in line:
                imgSrc = line[12:-3]
            if "<span class=\"name\"" in line:
                pdName = line[19:-7]
                img_pd = [title, div, cate, cate_link, cate_flag, sub_cate, sub_id, pdName, imgSrc, pdPage]
                pdList.append(img_pd)
                #print(img_pd)
        
###############################################################################################################
    #만약 SubCategory가 없다면
    else:
        sub_cate = 0
        sub_id = 0
        #분류가 푸드라인업 이라면 #상품개수 없음, javascript가 다름
        if div == "푸드라인업":
            while True:
                sleep(2)
                html = driver.page_source
                food_page = BeautifulSoup(html)
                find_more = food_page.find_all("a", {"class" : "more"})
                for line in find_more:
                    find_more = line.text
                #print(find_more)
                if find_more == "more":
                    element = driver.find_element_by_partial_link_text("more")
                    element.click()
                if find_more == "close":
                    break                
            
            sleep(5)
            #상품 목록 정리하기
            pdhtml= str(food_page.find("ul", {"id" : "goodsListUl"}))

            pdhtml = pdhtml.replace("> <", ">\n<")
            pdhtml = pdhtml.replace("[", "\n")
            pdhtml = pdhtml.replace("]", "")
            pdhtml = pdhtml.split("\n")
            #print(pdhtml) #한번 출력
            
            img_pd = []
            imgSrc = ""
            pdPage = ""
            pdName = ""

            for line in pdhtml:
                if "<img src=" in line:
                    imgSrc = line[30:-10]
                if "<span class=\"name\"" in line:
                    pdName = line[19:-27]
                if "<a class=\"detail\"" in line:
                    pdPage = line[24:-10]
                    img_pd = [title, div, cate, cate_link, cate_flag, sub_cate, sub_id, pdName, imgSrc, pdPage]
                    pdList.append(img_pd)
            #print(pdList)
        ##############################################################################################
        else:
            #subcategory의 기본 페이지 상품 가져오기
            sleep(5)
            html = driver.page_source
            sub_page = BeautifulSoup(html)
            #print(sub_page) #얘도 한번인데....

            #subcategory의 상품개수 가져오기
            resultCnt = sub_page.find_all("span", {"id" : "resultCount"})
            for cnt in resultCnt:
                resultCnt = cnt.text
            resultCnt = int(resultCnt)
            #print(sub_page) 얘도 한번!

            #more javascript를 실행 할 것인가?
            add_more = resultCnt - 25 #기본 개수 빼기
            mok = 0
            nam = 0
            if add_more>0:
                mok = int(add_more/10) + 1
                nam = (add_more%10)
                if nam != 0:
                    mok += 1
            #print(sub_page) #한번

            #more javascript를 실행해야 한다면
            if mok!=0:
                for i in range(mok):
                    driver.execute_script("selectGoodsList('','',10);")
                html = driver.page_source
                sub_page2 = BeautifulSoup(html)
            #print(sub_page) #연관 없음

            #상품 목록 정리하기
            pdhtml= str(sub_page.find("ul", {"id" : "tbodyList"}))
            # pdhtml = "<title:"+title+"><types:"+types+"><name:"+name+"><sub_cate:"+sub_cate+"><resultCnt:"+str(resultCnt)+">"+pdhtml
            #print(pdhtml) #한번 출력 
            #break
            #print(sub_page) #한번 출력

            pdhtml = pdhtml.replace("><", ">\n<")
            pdhtml = pdhtml.replace("[", "\n")
            pdhtml = pdhtml.replace("]", "")
            pdhtml = pdhtml.split("\n")
            #print(pdhtml) #한번 출력

            img_pd = []
            imgSrc = ""
            pdName = ""
            pdPage = ""

            for line in pdhtml:
                if "<a href=" in line:
                    pdPage = line[9:-2]
                if "<img src=" in line:
                    imgSrc = line[12:-3]
                if "<span class=\"name\"" in line:
                    pdName = line[19:-7]
                    img_pd = [title, div, cate, cate_link, cate_flag, sub_cate, sub_id, pdName, imgSrc, pdPage]
                    pdList.append(img_pd)
                    #print(img_pd)
                    #break
            #print(pdList)
    driver.quit()
    sleep(10)
# Out:
# /Users/SeulA/anaconda/lib/python3.6/site-packages/bs4/__init__.py:181: UserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("lxml"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 193 of the file /Users/SeulA/anaconda/lib/python3.6/runpy.py. To get rid of this warning, change code that looks like this:
#
#  BeautifulSoup([your markup])
#
# to this:
#
#  BeautifulSoup([your markup], "lxml")
#
#   markup_type=markup_type))
# ...

# %% [markdown]
# # DataFrame

# %%
df_category = ["title", "div", "cate", "cate_link", "cate_flag", "sub_cate", "sub_id"]
df_product = []
df_product = df_category
df_product.append("pdName")
df_product.append("pdImg")
df_product.append("pdPage")

# %%
print(df_product)
# Out:
# ['title', 'div', 'cate', 'cate_link', 'cate_flag', 'sub_cate', 'sub_id', 'pdName', 'pdImg', 'pdPage']

# %%
test = pd.DataFrame(pdList, columns=df_product)
test
# Out:
#          title    div    cate  \
# 0     SKINCARE    유형별     클렌징
# 1     SKINCARE    유형별     클렌징
# 2     SKINCARE    유형별     클렌징
# 3     SKINCARE    유형별     클렌징
# 4     SKINCARE    유형별     클렌징
# 5     SKINCARE    유형별     클렌징
# 6     SKINCARE    유형별     클렌징
# 7     SKINCARE    유형별     클렌징
# 8     SKINCARE    유형별     클렌징
# 9     SKINCARE    유형별     클렌징
# 10    SKINCARE    유형별     클렌징
# 11    SKINCARE    유형별     클렌징
# 12    SKINCARE    유형별     클렌징
# 13    SKINCARE    유형별     클렌징
# 14    SKINCARE    유형별     클렌징
# 15    SKINCARE    유형별     클렌징
# 16    SKINCARE    유형별     클렌징
# 17    SKINCARE    유형별     클렌징
# 18    SKINCARE    유형별     클렌징
# 19    SKINCARE    유형별     클렌징
# 20    SKINCARE    유형별     클렌징
# 21    SKINCARE    유형별     클렌징
# 22    SKINCARE    유형별     클렌징
# 23    SKINCARE    유형별     클렌징
# 24    SKINCARE    유형별     클렌징
# 25    SKINCARE    유형별     클렌징
# 26    SKINCARE    유형별     클렌징
# 27    SKINCARE    유형별     클렌징
# 28    SKINCARE    유형별     클렌징
# 29    SKINCARE    유형별     클렌징
# ...

# %%
test.to_csv("skinfood_productList.csv", index=False)

# %%
pd_id = "P0000000000000000768"

# %%
java = "javascript:ShopProductList.fn.goProductView('"+pd_id+"');"
print(java)
# Out:
# javascript:ShopProductList.fn.goProductView('P0000000000000000768');

# %%
hello = pd.read_csv("skinfood_productList.csv", encoding="utf-8")

# %%
hello
# Out:
#          title    div    cate  \
# 0     SKINCARE    유형별     클렌징
# 1     SKINCARE    유형별     클렌징
# 2     SKINCARE    유형별     클렌징
# 3     SKINCARE    유형별     클렌징
# 4     SKINCARE    유형별     클렌징
# 5     SKINCARE    유형별     클렌징
# 6     SKINCARE    유형별     클렌징
# 7     SKINCARE    유형별     클렌징
# 8     SKINCARE    유형별     클렌징
# 9     SKINCARE    유형별     클렌징
# 10    SKINCARE    유형별     클렌징
# 11    SKINCARE    유형별     클렌징
# 12    SKINCARE    유형별     클렌징
# 13    SKINCARE    유형별     클렌징
# 14    SKINCARE    유형별     클렌징
# 15    SKINCARE    유형별     클렌징
# 16    SKINCARE    유형별     클렌징
# 17    SKINCARE    유형별     클렌징
# 18    SKINCARE    유형별     클렌징
# 19    SKINCARE    유형별     클렌징
# 20    SKINCARE    유형별     클렌징
# 21    SKINCARE    유형별     클렌징
# 22    SKINCARE    유형별     클렌징
# 23    SKINCARE    유형별     클렌징
# 24    SKINCARE    유형별     클렌징
# 25    SKINCARE    유형별     클렌징
# 26    SKINCARE    유형별     클렌징
# 27    SKINCARE    유형별     클렌징
# 28    SKINCARE    유형별     클렌징
# 29    SKINCARE    유형별     클렌징
# ...

# %%
hihi = len(hello)

# %%
addTotal = []
final = []
for i in range(hihi):
    if "유형별" in hello["div"][i]:
        final = [hello["title"][i], hello["cate"][i], hello["pdName"][i], hello["pdImg"][i]]
        addTotal.append(final)

# %%
skinfood_final = pd.DataFrame(addTotal, columns = ["cate", "sub_cate", "pdName", "pdImg"])

# %% [raw]
# skinfoo

# %%
skinfood_final
# Out:
#           cate  sub_cate                                pdName  \
# 0     SKINCARE       클렌징                    에그 화이트 퍼펙트 포어 머랭 폼
# 1     SKINCARE       클렌징                   에그 화이트 퍼펙트 포어 클렌징 폼
# 2     SKINCARE       클렌징                            허니 밀 클렌징 폼
# 3     SKINCARE       클렌징                    블랙슈가 퍼펙트 오일 클렌징 티슈
# 4     SKINCARE       클렌징                          블랙슈가 퍼펙트 버블폼
# 5     SKINCARE       클렌징                         비터 그린 클레이 투 폼
# 6     SKINCARE       클렌징                          티트리 소프트 버블 폼
# 7     SKINCARE       클렌징                             티트리 클렌징 폼
# 8     SKINCARE       클렌징                        블랙슈가 퍼펙트 스크럽 폼
# 9     SKINCARE       클렌징                렛츠 무스 치즈  클렌징 폼 JUMBO
# 10    SKINCARE       클렌징                 렛츠 밀키 밀크  클렌징 폼 JUMBO
# 11    SKINCARE       클렌징               렛츠 프레시 요거트  클렌징 폼 JUMBO
# 12    SKINCARE       클렌징                       렛츠 밀키 밀크 버블 클렌저
# 13    SKINCARE       클렌징                              렛츠 클렌징 폼
# ...

# %%
final = len(skinfood_final)

# %%
for i in range(final):
    skinfood_final["pdImg"][i] = "https://" + skinfood_final["pdImg"][i]

# %%
skinfood_final
# Out:
#           cate  sub_cate                                pdName  \
# 0     SKINCARE       클렌징                    에그 화이트 퍼펙트 포어 머랭 폼
# 1     SKINCARE       클렌징                   에그 화이트 퍼펙트 포어 클렌징 폼
# 2     SKINCARE       클렌징                            허니 밀 클렌징 폼
# 3     SKINCARE       클렌징                    블랙슈가 퍼펙트 오일 클렌징 티슈
# 4     SKINCARE       클렌징                          블랙슈가 퍼펙트 버블폼
# 5     SKINCARE       클렌징                         비터 그린 클레이 투 폼
# 6     SKINCARE       클렌징                          티트리 소프트 버블 폼
# 7     SKINCARE       클렌징                             티트리 클렌징 폼
# 8     SKINCARE       클렌징                        블랙슈가 퍼펙트 스크럽 폼
# 9     SKINCARE       클렌징                렛츠 무스 치즈  클렌징 폼 JUMBO
# 10    SKINCARE       클렌징                 렛츠 밀키 밀크  클렌징 폼 JUMBO
# 11    SKINCARE       클렌징               렛츠 프레시 요거트  클렌징 폼 JUMBO
# 12    SKINCARE       클렌징                       렛츠 밀키 밀크 버블 클렌저
# 13    SKINCARE       클렌징                              렛츠 클렌징 폼
# ...

# %%
skinfood_final.to_csv("skinfood_final.csv", encoding="utf-8", index=False)
