# %% [markdown]
# # Youtuber Playlist Video List

# %%
from selenium import webdriver
from bs4 import BeautifulSoup
import pandas as pd

# %%
youtube_address = "https://www.youtube.com"
user_name = "PONY Syndrome"
user_address = "https://www.youtube.com/channel/UCT-_4GqC-yLY1xtTHhwY0hA"
youtuber_playlist_video_list_path = "../csv/youtuber_playlist_video_list.csv"

# %%
tabs_info_script = "return window['ytInitialData']['contents']['twoColumnBrowseResultsRenderer']['tabs']"
playlist_tabs_script = "{}[2]['tabRenderer']['endpoint']['commandMetadata']['webCommandMetadata']['url']".format(tabs_info_script)
playlist_item_script = "{}[2]['tabRenderer']['content']['sectionListRenderer']['contents'][0] \
                        ['itemSectionRenderer']['contents'][0]['gridRenderer']['items']".format(tabs_info_script)

item_script = "{}[0]['tabRenderer']['content']['sectionListRenderer']['contents'][0]['itemSectionRenderer'] \
                ['contents'][0]['playlistVideoListRenderer']['contents']".format(tabs_info_script)

# %%
driver = webdriver.Firefox()

# %%
driver.get(user_address)
playlist_tabs = youtube_address + driver.execute_script(playlist_tabs_script)

# %%
driver.get(playlist_tabs)
playlist = driver.execute_script(playlist_item_script)

# %%
playlist_video_list = []
for item in playlist:
    playlist_title = item['gridPlaylistRenderer']['title']['runs'][0]['text']
    playlist_url = youtube_address + item['gridPlaylistRenderer']['viewPlaylistText']['runs'][0]['navigationEndpoint']['commandMetadata']['webCommandMetadata']['url']

    driver.get(playlist_url)
    playlist_item_list = driver.execute_script(item_script)
    for item in playlist_item_list:
        video_title = item['playlistVideoRenderer']['title']['simpleText']
        video_address = youtube_address + item['playlistVideoRenderer']['navigationEndpoint']['commandMetadata']['webCommandMetadata']['url']
        video_thumbnail = item['playlistVideoRenderer']['thumbnail']['thumbnails'][0]['url']
        video_thumbnail = video_thumbnail.split('?sqp')[0].replace('hqdefault.jpg', 'maxresdefault.jpg').replace("//s", "https://s")
        
        playlist_video_list.append([user_name, playlist_title, playlist_url, video_title, video_address, video_thumbnail])

# %%
column_list = ["youtuber_name", "playlist_title", "playlist_url", "video_title", "video_address", "video_thumbnail"]
youtuber_playlist_video_list_df = pd.DataFrame(playlist_video_list, columns=column_list)
youtuber_playlist_video_list_df.to_csv(youtuber_playlist_video_list_path, encoding="utf-8", index=False)
youtuber_playlist_video_list_df.head(10)
# Out:
#    youtuber_name         playlist_title  \
# 0  PONY Syndrome   💜포니야부탁해💜 PONY ON-AIR
# 1  PONY Syndrome   💜포니야부탁해💜 PONY ON-AIR
# 2  PONY Syndrome   💜포니야부탁해💜 PONY ON-AIR
# 3  PONY Syndrome   💜포니야부탁해💜 PONY ON-AIR
# 4  PONY Syndrome   💜포니야부탁해💜 PONY ON-AIR
# 5  PONY Syndrome   💜포니야부탁해💜 PONY ON-AIR
# 6  PONY Syndrome   💜포니야부탁해💜 PONY ON-AIR
# 7  PONY Syndrome   💜포니야부탁해💜 PONY ON-AIR
# 8  PONY Syndrome   💜포니야부탁해💜 PONY ON-AIR
# 9  PONY Syndrome  PONY The Globetrotter
#
#                                         playlist_url  \
# 0  https://www.youtube.com/playlist?list=PLj6FeOw...
# 1  https://www.youtube.com/playlist?list=PLj6FeOw...
# 2  https://www.youtube.com/playlist?list=PLj6FeOw...
# 3  https://www.youtube.com/playlist?list=PLj6FeOw...
# 4  https://www.youtube.com/playlist?list=PLj6FeOw...
# 5  https://www.youtube.com/playlist?list=PLj6FeOw...
# 6  https://www.youtube.com/playlist?list=PLj6FeOw...
# 7  https://www.youtube.com/playlist?list=PLj6FeOw...
# 8  https://www.youtube.com/playlist?list=PLj6FeOw...
# 9  https://www.youtube.com/playlist?list=PLj6FeOw...
#
#                                          video_title  \
# 0     💜포니야부탁해💜 티져 / 'PONY ON-AIR' TEASER (With subs)
# 1  💜포니야부탁해💜 1화 '농사를 부탁해' / 'PONY ON-AIR'  EP-01 (...
# 2  💜포니야부탁해💜  2화 '농사를 부탁해' / 'PONY ON-AIR'  EP-02 ...
# 3  💜포니야부탁해💜 3화 '가족사진을 부탁해' / 'PONY ON-AIR'  EP-03...
# 4  💜포니야부탁해💜 4화 '가족사진을 부탁해' / 'PONY ON-AIR'  EP-04...
# 5  💜포니야부탁해💜 5화 '한국 친구가 돼주길 부탁해' / 'PONY ON-AIR'  ...
# 6  💜포니야부탁해💜 6화 '한국 친구가 돼주길 부탁해' / 'PONY ON-AIR'  ...
# 7  💜포니야부탁해💜 7화 '육아 스트레스를 부탁해' / 'PONY ON-AIR' EP-...
# 8  💜포니야부탁해💜 마지막 화 '육아 스트레스를 부탁해' / 'PONY ON-AIR' ...
# 9  PONY THE GLOBETROTTER + GRWM (With subs) - TOK...
#
#                                        video_address  \
# 0  https://www.youtube.com/watch?v=Gf70DmLChhM&in...
# 1  https://www.youtube.com/watch?v=1X8LmP7OeL8&in...
# 2  https://www.youtube.com/watch?v=dBniz5wq4XY&in...
# 3  https://www.youtube.com/watch?v=6f24_0H__tU&in...
# 4  https://www.youtube.com/watch?v=FXPmjNWR2xo&in...
# 5  https://www.youtube.com/watch?v=UZlI0Ow-20s&in...
# 6  https://www.youtube.com/watch?v=s1DjRT82fMc&in...
# 7  https://www.youtube.com/watch?v=YP7aTW35zRQ&in...
# 8  https://www.youtube.com/watch?v=KFgLQHBhAoc&in...
# 9  https://www.youtube.com/watch?v=708m0DBcsaM&in...
#
#                                      video_thumbnail
# 0  https://i.ytimg.com/vi/Gf70DmLChhM/maxresdefau...
# 1  https://i.ytimg.com/vi/1X8LmP7OeL8/maxresdefau...
# 2  https://i.ytimg.com/vi/dBniz5wq4XY/maxresdefau...
# 3  https://i.ytimg.com/vi/6f24_0H__tU/maxresdefau...
# 4  https://i.ytimg.com/vi/FXPmjNWR2xo/maxresdefau...
# 5  https://i.ytimg.com/vi/UZlI0Ow-20s/maxresdefau...
# 6  https://i.ytimg.com/vi/s1DjRT82fMc/maxresdefau...
# 7  https://i.ytimg.com/vi/YP7aTW35zRQ/maxresdefau...
# 8  https://i.ytimg.com/vi/KFgLQHBhAoc/maxresdefau...
# 9  https://i.ytimg.com/vi/708m0DBcsaM/maxresdefau...
