# %% [markdown]
# # Youtuber Video List
# * video_title, video_address, video_thumbnail

# %%
import pandas as pd
from selenium import webdriver
from bs4 import BeautifulSoup
import time

# %%
youtube_address = "https://www.youtube.com"
youtuber_list_path = "../csv/youtuber_list.csv"
youtuber_video_list_path = "../csv/youtuber_video_list.csv"

# %%
data_script = "return window['ytInitialData']['contents']['twoColumnBrowseResultsRenderer'] \
                ['tabs'][1]['tabRenderer']['content']['sectionListRenderer']['contents'][0] \
                ['itemSectionRenderer']['contents'][0]['gridRenderer']"

scroll_script = "window.scrollTo(0, document.getElementById('items').offsetHeight)"
continue_script = "{}['continuations']['length']".format(data_script)

item_script = "{}['items']".format(data_script)

item_cnt_script = "{}['length']".format(item_script)
item_title_script = "{}[{}]['gridVideoRenderer']['title']['simpleText']"
item_address_script = "{}[{}]['gridVideoRenderer']['navigationEndpoint']['commandMetadata']['webCommandMetadata']"
item_thumbnail_script = "{}[{}]['gridVideoRenderer']['thumbnail']['thumbnails']"

# %%
youtuber_df = pd.read_csv(youtuber_list_path, encoding="utf-8")
youtuber_df.head(3)
# Out:
#   user_name                                       user_address  \
# 0        씬님              https://www.youtube.com/user/Hines382
# 1       윤짜미            https://www.youtube.com/user/yooncharmi
# 2       이사배  https://www.youtube.com/channel/UC9kmlDcqksaOn...
#
#                                       videos_address
# 0       https://www.youtube.com/user/Hines382/videos
# 1     https://www.youtube.com/user/yooncharmi/videos
# 2  https://www.youtube.com/channel/UC9kmlDcqksaOn...

# %%
driver = webdriver.Firefox()

# %%
youtuber_video_list = []

for i, row in youtuber_df.iterrows():
    driver.get(row["videos_address"])
    time.sleep(5)
    
    while(True):
        driver.execute_script(scroll_script)
        time.sleep(5)     
        script_result = driver.execute_script(continue_script)
        if script_result == 0:
            break
    
    source = driver.page_source
    bs = BeautifulSoup(source, "html.parser")
    
#     item_list = bs.find_all("a", {"class" : "yt-simple-endpoint style-scope ytd-grid-video-renderer"})[1:]
    item_cnt = driver.execute_script(item_cnt_script)
    youtuber_name = row['user_name']    
    
    for cnt in range(item_cnt):
        video_title = driver.execute_script(item_title_script.format(item_script, cnt))
        video_address = driver.execute_script(item_address_script.format(item_script, cnt))['url']
        video_thumbnail = driver.execute_script(item_thumbnail_script.format(item_script, cnt))[0]['url']
        video_thumbnail = video_thumbnail.split('?sqp')[0].replace('hqdefault.jpg', 'maxresdefault.jpg')
        
        youtuber_video_list.append([youtuber_name, video_title, youtube_address + video_address, video_thumbnail])

    print("{}: {}".format(row['user_name'], item_cnt))
print("TOTAL: {}".format(len(youtuber_video_list)))
# Out:
# 씬님: 526
# 윤짜미: 253
# 이사배: 423
# 포니: 101
# Lena's Pocket Beauty: 137
# 영주: 298
# 윤새: 215
# 회사원(calarygirl): 288
# 라뮤끄: 240
# 곽토리: 279
# 김기수: 284
# dayeong's beauty drawing: 264
# 루나(루나의 알파벳): 111
# 꽁지: 425
# Yojin 조효진: 175
# YENNY 예니: 41
# 썸블리: 197
# EVA 에바: 207
# 써니채널 Sunny's Channel: 130
# Daddoa 다또아: 90
# yeondukong 연두콩: 232
# Yoo True: 605
# TOTAL: 5521

# %%
driver.quit()

# %%
column_list = ["youtuber_name", "video_title", "video_address", "video_thumbnail"]
youtuber_video_list_df = pd.DataFrame(youtuber_video_list, columns=column_list)
youtuber_video_list_df.to_csv(youtuber_video_list_path, encoding="utf-8", index=False)
youtuber_video_list_df.head(10)
# Out:
#   youtuber_name                                        video_title  \
# 0            씬님  🎃주황색 미국호박 난생 처음봄;; "미쿡호박"에서 영감을 받은 겟레디윗미! 오렌지 ...
# 1            씬님  🆘한국보다10배 더 무섭다!🆘 유니버셜 스튜디오 호러나이트// 호러메이즈 체험 | ...
# 2            씬님  🎪좀비를 꼬시러 가는 겟레디윗미🎪 "유니버셜 스튜디오 호러나이트" 같이화장해요! |...
# 3            씬님  💋1930's 상하이 모던 레트로 메이크업 Modern retro makeup | ...
# 4            씬님                       로드샵 원브랜드 메이크업 : 삐아 #2 | SSIN
# 5            씬님                       로드샵 원브랜드 메이크업 : 삐아 #1 | SSIN
# 6            씬님         🎒대만으로 급 떠나는 여행 겟레디윗미! 이것이 마이리얼트립인가. | SSIN
# 7            씬님  🥀핑크극복프로젝트🥀4.뮤트핑크 Overcoming the fear of PINK :...
# 8            씬님                      🧡벽돌 분쇄 ; 가을 레드브라운 메이크업 | SSIN
# 9            씬님       씬팁📝집중설명 : 베이스 메이크업 [다크서클 없애부락리...] | SSINTIP
#
#                                  video_address  \
# 0  https://www.youtube.com/watch?v=QUcW8hREwDQ
# 1  https://www.youtube.com/watch?v=TxEbm6z25y0
# 2  https://www.youtube.com/watch?v=2FJlzki8Fw8
# 3  https://www.youtube.com/watch?v=LzXZDPln_wY
# 4  https://www.youtube.com/watch?v=ovMZ4VlHflc
# 5  https://www.youtube.com/watch?v=mig3VP0iWAE
# 6  https://www.youtube.com/watch?v=vRMKTbwMJUw
# 7  https://www.youtube.com/watch?v=-2KMWCTD1y8
# 8  https://www.youtube.com/watch?v=ay_a4p8BMVY
# 9  https://www.youtube.com/watch?v=BPX3mtVOPBc
#
#                                      video_thumbnail
# 0  https://i.ytimg.com/vi/QUcW8hREwDQ/maxresdefau...
# 1  https://i.ytimg.com/vi/TxEbm6z25y0/maxresdefau...
# 2  https://i.ytimg.com/vi/2FJlzki8Fw8/maxresdefau...
# 3  https://i.ytimg.com/vi/LzXZDPln_wY/maxresdefau...
# 4  https://i.ytimg.com/vi/ovMZ4VlHflc/maxresdefau...
# 5  https://i.ytimg.com/vi/mig3VP0iWAE/maxresdefau...
# 6  https://i.ytimg.com/vi/vRMKTbwMJUw/maxresdefau...
# 7  https://i.ytimg.com/vi/-2KMWCTD1y8/maxresdefau...
# 8  https://i.ytimg.com/vi/ay_a4p8BMVY/maxresdefau...
# 9  https://i.ytimg.com/vi/BPX3mtVOPBc/maxresdefau...
