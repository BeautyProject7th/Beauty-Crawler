# %% [markdown]
# # 아리따움

# %%
import pandas as pd
import numpy as np
import requests
from bs4 import BeautifulSoup
from selenium import webdriver
from slacker import Slacker
from time import sleep
from selenium.webdriver.common.keys import Keys

# %%
token = 'xoxb-141438920821-DH6BthlLsHmJt306FV8ELkl6'
slack = Slacker(token)

# %%
site = "http://www.aritaum.com/shop/pr/shop_pr_product_list.do?i_sCategorycd1=CTG001"

# %%
driver = webdriver.Firefox()
driver.get(site)
sleep(3)

# %%
html = driver.page_source
page = BeautifulSoup(html)
# Out:
# /Users/SeulA/anaconda/lib/python3.6/site-packages/bs4/__init__.py:181: UserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("lxml"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 193 of the file /Users/SeulA/anaconda/lib/python3.6/runpy.py. To get rid of this warning, change code that looks like this:
#
#  BeautifulSoup([your markup])
#
# to this:
#
#  BeautifulSoup([your markup], "lxml")
#
#   markup_type=markup_type))

# %%
category = page.find_all("div", {"class" : "shoppingCategory"})

# %%
category = str(category)

# %%
category = category.split("<a class=\"a_categorycd1")

# %%
category = category[1:8]

# %%
for i in range(len(category)):
    category[i] = "<a class=\"a_categorycd1" + str(category[i])
    category[i] = str(category[i])
    category[i] = category[i].replace("\n", "")
    category[i] = category[i].split("<ul><li class=\"li_category2\">")

# %%
line = category[0]
print(line[1])
# Out:
# <a class="a_categorycd2" href="#" id="CTG008"><em>클렌징</em><span class="cnt">(68)</span></a><div class="depth3" style="display: none;"><ul><li class="li_category3"><a class="a_categorycd3" href="#" id="CTG009"><em>메이크업 리무버</em><span class="cnt">(23)</span></a></li><li class="li_category3"><a class="a_categorycd3" href="#" id="CTG010"><em>페이스 워시</em><span class="cnt">(37)</span></a></li><li class="li_category3"><a class="a_categorycd3" href="#" id="CTG011"><em>필링 &amp; 스크럽</em><span class="cnt">(12)</span></a></li></ul></div></li><li class="li_category2"><a class="a_categorycd2" href="#" id="CTG012"><em>모이스처라이징</em><span class="cnt">(128)</span></a><div class="depth3" style="display: none;"><ul><li class="li_category3"><a class="a_categorycd3" href="#" id="CTG013"><em>스킨 &amp; 토너</em><span class="cnt">(31)</span></a></li><li class="li_category3"><a class="a_categorycd3" href="#" id="CTG014"><em>로션 &amp; 에멀젼 </em><span class="cnt">(25)</span></a></li><li class="li_category3"><a class="a
# ...

# %%
title, title_id, title_class, title_cnt, cate, cate_id, cate_class, cate_cnt, sub_cate, sub_id, sub_class, sub_cnt = "", "", "", "", "", "", "", "", "", "", "", ""

# %%
sum_list = []
final_list = []

for i in range(len(category)):
    line = category[i]
    line1 = line[0]
    line1 = line1.replace("><", ">\n<")
    line1 = line1.split("\n")

    for new in line1:
        #print(new)
        if "<a class=" in new:
            title_class = new[10:-23]
            #print(title_class)
            if "id=" in new:
                title_id = new[38:-2]
                #print(title_id)
        if "<em>" in new:
            title = new[4:-5]
            #print(title)
        if "<span class=" in new:
            title_cnt = new[19:-8]
            #print(title_cnt)
            titleList = [title_class, title_id, title, title_cnt]
            #print(titleList)
        
    line2 = line[1]
    #print(line2)
    line2 = line2.split("<a class=\"a_categorycd2")
    line2 = line2[1:]
    for i in range(len(line2)):
        new_newline2= "<a class=\"a_categorycd2" + str(line2[i])
        line2[i] = new_newline2

    num = 0
    for new in line2:
        if "<div class=\"depth3" in new:
            class3 = str(new)
            class3 = class3.replace("<ul><li class=\"li_category3\">", "\n")
            class3 = class3.split("\n")
            
            cate_html = class3[0]
            cate_html = str(cate_html)
            cate_html = cate_html.replace("><", ">\n<")
            cate_html = cate_html.split("\n")
            
            for new_cate in cate_html:
                #print(new_cate)
                #cateSp = new_cate.replace("><", ">\n<")
                #cateSp = new_cate.split("\n")
                #print(cateSp)
                if "a_categorycd2" in new_cate:
                    cate_class = new_cate[10:-23]
                    cate_id = new_cate[38:-2]
                if "<em>" in new_cate:
                    cate = new_cate[4:-5]
                if "<span class=" in new_cate:
                    cate_cnt = new_cate[19:-8]
                    cateList = [cate_class, cate_id, cate, cate_cnt]
                    #print(cateList)
                    
            sub_html = class3[1]
            sub_html = str(sub_html)
            sub_html = sub_html.replace("><", ">\n<")
            sub_html = sub_html.split("\n")
            #print(sub_html)
            
            for new_sub in sub_html:
                if "a class=\"a_categorycd3" in new_sub:
                    sub_class = new_sub[10:-23]
                    sub_id = new_sub[38:-2]
                if "<em>" in new_sub:
                    sub_cate = new_sub[4:-5]
                if "<span class=" in new_sub:
                    sub_cnt = new_sub[19:-8]
                    subList = [sub_class, sub_id, sub_cate, sub_cnt]
                    #print(subList)
                    sum_list = titleList + cateList + subList
                    final_list.append(sum_list)
                    print(sum_list)

        else:
            cate_html = new
            cate_html = str(cate_html)
            cate_html = cate_html.replace("><", ">\n<")
            cate_html = cate_html.split("\n")
            
            for new_cate in cate_html:
                sub_cate = str(0)
                sub_id = str(0)
                sub_class = str(0)
                sub_cnt = str(0)
                subList = [sub_class, sub_id, sub_cate, sub_cnt] 
                if "a class=\"a_categorycd2" in new_cate:
                    cate_class = new_cate[10:-23]
                    cate_id = new_cate[38:-2]
                if "<em>" in new_cate:
                    cate = new_cate[4:-5]
                if "<span class=" in new_cate:
                    cate_cnt = new_cate[19:-8]
                    cateList = [cate_class, cate_id, cate, cate_cnt]
                    #print(subList)
                    #print(cateList)
                    sum_list = titleList + cateList + subList
                    final_list.append(sum_list)
                    print(sum_list)
# Out:
# ['a_categorycd1', 'CTG001', '스킨케어', '273', 'a_categorycd2', 'CTG008', '클렌징', '68', 'a_categorycd3', 'CTG009', '메이크업 리무버', '23']
# ['a_categorycd1', 'CTG001', '스킨케어', '273', 'a_categorycd2', 'CTG008', '클렌징', '68', 'a_categorycd3', 'CTG010', '페이스 워시', '37']
# ['a_categorycd1', 'CTG001', '스킨케어', '273', 'a_categorycd2', 'CTG008', '클렌징', '68', 'a_categorycd3', 'CTG011', '필링 &amp; 스크럽', '12']
# ['a_categorycd1', 'CTG001', '스킨케어', '273', 'a_categorycd2', 'CTG012', '모이스처라이징', '128', 'a_categorycd3', 'CTG013', '스킨 &amp; 토너', '31']
# ['a_categorycd1', 'CTG001', '스킨케어', '273', 'a_categorycd2', 'CTG012', '모이스처라이징', '128', 'a_categorycd3', 'CTG014', '로션 &amp; 에멀젼 ', '25']
# ['a_categorycd1', 'CTG001', '스킨케어', '273', 'a_categorycd2', 'CTG012', '모이스처라이징', '128', 'a_categorycd3', 'CTG015', '에센스 &amp; 세럼', '27']
# ['a_categorycd1', 'CTG001', '스킨케어', '273', 'a_categorycd2', 'CTG012', '모이스처라이징', '128', 'a_categorycd3', 'CTG016', '크림', '38']
# ...

# %%
print(final_list)
# Out:
# [['a_categorycd1', 'CTG001', '스킨케어', '273', 'a_categorycd2', 'CTG008', '클렌징', '68', 'a_categorycd3', 'CTG009', '메이크업 리무버', '23'], ['a_categorycd1', 'CTG001', '스킨케어', '273', 'a_categorycd2', 'CTG008', '클렌징', '68', 'a_categorycd3', 'CTG010', '페이스 워시', '37'], ['a_categorycd1', 'CTG001', '스킨케어', '273', 'a_categorycd2', 'CTG008', '클렌징', '68', 'a_categorycd3', 'CTG011', '필링 &amp; 스크럽', '12'], ['a_categorycd1', 'CTG001', '스킨케어', '273', 'a_categorycd2', 'CTG012', '모이스처라이징', '128', 'a_categorycd3', 'CTG013', '스킨 &amp; 토너', '31'], ['a_categorycd1', 'CTG001', '스킨케어', '273', 'a_categorycd2', 'CTG012', '모이스처라이징', '128', 'a_categorycd3', 'CTG014', '로션 &amp; 에멀젼 ', '25'], ['a_categorycd1', 'CTG001', '스킨케어', '273', 'a_categorycd2', 'CTG012', '모이스처라이징', '128', 'a_categorycd3', 'CTG015', '에센스 &amp; 세럼', '27'], ['a_categorycd1', 'CTG001', '스킨케어', '273', 'a_categorycd2', 'CTG012', '모이스처라이징', '128', 'a_categorycd3', 'CTG016', '크림', '38'], ['a_categorycd1', 'CTG001', '스킨케어', '273', 'a_categorycd2', 'CTG01
# ...

# %%
dfName = ["title_class", "title_id", "title", "title_cnt", "cate_class", "cate_id", "cate", "cate_cnt", "sub_class", "sub_id", "sub_cate", "sub_cnt"]

# %%
df = pd.DataFrame(final_list, columns=dfName)

# %%
df
# Out:
#       title_class title_id          title title_cnt     cate_class cate_id  \
# 0   a_categorycd1   CTG001           스킨케어       273  a_categorycd2  CTG008
# 1   a_categorycd1   CTG001           스킨케어       273  a_categorycd2  CTG008
# 2   a_categorycd1   CTG001           스킨케어       273  a_categorycd2  CTG008
# 3   a_categorycd1   CTG001           스킨케어       273  a_categorycd2  CTG012
# 4   a_categorycd1   CTG001           스킨케어       273  a_categorycd2  CTG012
# 5   a_categorycd1   CTG001           스킨케어       273  a_categorycd2  CTG012
# 6   a_categorycd1   CTG001           스킨케어       273  a_categorycd2  CTG012
# 7   a_categorycd1   CTG001           스킨케어       273  a_categorycd2  CTG012
# 8   a_categorycd1   CTG001           스킨케어       273  a_categorycd2  CTG012
# 9   a_categorycd1   CTG001           스킨케어       273  a_categorycd2  CTG019
# 10  a_categorycd1   CTG001           스킨케어       273  a_categorycd2  CTG019
# ...

# %% [markdown]
# # 아리따움 주소

# %%
basic = "http://www.aritaum.com/shop/pr/shop_pr_product_list.do?"

# %%
new_df = df

# %%
change = len(new_df)

# %%
capital1 = "Categorycd1"
capital2 = "Categorycd2"
capital3 = "Categorycd3"

for i in range(change):
    #capital = new_df["title_class"][i]
    new_df["title_class"][i] = capital1
    #capital = new_df["cate_class"][i]
    new_df["cate_class"][i] = capital2
    capital = new_df["sub_class"][i]
    if capital != '0':
        new_df["sub_class"][i] = capital3

# %%
new_df
# Out:
#     title_class title_id          title title_cnt   cate_class cate_id  \
# 0   Categorycd1   CTG001           스킨케어       273  Categorycd2  CTG008
# 1   Categorycd1   CTG001           스킨케어       273  Categorycd2  CTG008
# 2   Categorycd1   CTG001           스킨케어       273  Categorycd2  CTG008
# 3   Categorycd1   CTG001           스킨케어       273  Categorycd2  CTG012
# 4   Categorycd1   CTG001           스킨케어       273  Categorycd2  CTG012
# 5   Categorycd1   CTG001           스킨케어       273  Categorycd2  CTG012
# 6   Categorycd1   CTG001           스킨케어       273  Categorycd2  CTG012
# 7   Categorycd1   CTG001           스킨케어       273  Categorycd2  CTG012
# 8   Categorycd1   CTG001           스킨케어       273  Categorycd2  CTG012
# 9   Categorycd1   CTG001           스킨케어       273  Categorycd2  CTG019
# 10  Categorycd1   CTG001           스킨케어       273  Categorycd2  CTG019
# 11  Categorycd1   CTG001           스킨케어       273  Categorycd2  CTG019
# ...

# %%
#i_sCategorycd1=CTG001&i_sCategorycd2=CTG008&i_sCategorycd3=CTG009

# %%
reLink = []
for i in range(change):
    title_class = new_df["title_class"][i]
    title_id = new_df["title_id"][i]
    title = new_df["title"][i]
    title_cnt = new_df["title"][i]
    cate_class = new_df["cate_class"][i]
    cate_id = new_df["cate_id"][i]
    cate = new_df["cate"][i]
    cate_cnt = new_df["cate_cnt"][i]
    sub_class = new_df["sub_class"][i]
    sub_cnt = new_df["sub_cnt"][i]
    sub_cate = new_df["sub_cate"][i]
    sub_id = new_df["sub_id"][i]
    
    if sub_class != '0':
        catesite = "i_s" + title_class+"="+title_id+"&"+"i_s" + cate_class+"="+cate_id+"&"+"i_s" + sub_class+"="+sub_id
    else:
        catesite = "i_s" + title_class+"="+title_id+"&"+"i_s" + cate_class+"="+cate_id

    search = basic + catesite
    #print()
    category = [title_class, title_id, title, title_cnt, cate_class, cate_id, cate, cate_cnt, sub_class, sub_id, sub_cate, sub_cnt, search]
    
    reLink.append(category)

# %%
reLink
# Out:
# [['Categorycd1',
#   'CTG001',
#   '스킨케어',
#   '스킨케어',
#   'Categorycd2',
#   'CTG008',
#   '클렌징',
#   '68',
#   'Categorycd3',
#   'CTG009',
#   '메이크업 리무버',
#   '23',
#   'http://www.aritaum.com/shop/pr/shop_pr_product_list.do?i_sCategorycd1=CTG001&i_sCategorycd2=CTG008&i_sCategorycd3=CTG009'],
#  ['Categorycd1',
#   'CTG001',
#   '스킨케어',
#   '스킨케어',
#   'Categorycd2',
#   'CTG008',
#   '클렌징',
#   '68',
#   'Categorycd3',
#   'CTG010',
#   '페이스 워시',
#   '37',
#   'http://www.aritaum.com/shop/pr/shop_pr_product_list.do?i_sCategorycd1=CTG001&i_sCategorycd2=CTG008&i_sCategorycd3=CTG010'],
#  ['Categorycd1',
#   'CTG001',
#   '스킨케어',
#   '스킨케어',
#   'Categorycd2',
#   'CTG008',
#   '클렌징',
#   '68',
#   'Categorycd3',
#   'CTG011',
#   '필링 &amp; 스크럽',
#   '12',
#   'http://www.aritaum.com/shop/pr/shop_pr_product_list.do?i_sCategorycd1=CTG001&i_sCategorycd2=CTG008&i_sCategorycd3=CTG011'],
#  ['Categorycd1',
#   'CTG001',
#   '스킨케어',
#   '스킨케어',
#   'Categorycd2',
#   'CTG012',
# ...

# %%
head = ["title_class", "title_id", "title", "title_cnt", "cate_class", "cate_id", "cate", "cate_cnt", "sub_class", "sub_id", "sub_cate", "sub_cnt", "site"]

# %%
df2 = pd.DataFrame(reLink, columns = head)

# %%
df2
# Out:
#     title_class title_id          title      title_cnt   cate_class cate_id  \
# 0   Categorycd1   CTG001           스킨케어           스킨케어  Categorycd2  CTG008
# 1   Categorycd1   CTG001           스킨케어           스킨케어  Categorycd2  CTG008
# 2   Categorycd1   CTG001           스킨케어           스킨케어  Categorycd2  CTG008
# 3   Categorycd1   CTG001           스킨케어           스킨케어  Categorycd2  CTG012
# 4   Categorycd1   CTG001           스킨케어           스킨케어  Categorycd2  CTG012
# 5   Categorycd1   CTG001           스킨케어           스킨케어  Categorycd2  CTG012
# 6   Categorycd1   CTG001           스킨케어           스킨케어  Categorycd2  CTG012
# 7   Categorycd1   CTG001           스킨케어           스킨케어  Categorycd2  CTG012
# 8   Categorycd1   CTG001           스킨케어           스킨케어  Categorycd2  CTG012
# 9   Categorycd1   CTG001           스킨케어           스킨케어  Categorycd2  CTG019
# 10  Categorycd1   CTG001           스킨케어           스킨케어  Categorycd2  CTG019
# ...

# %%
len(df2)
# Out:
# 76

# %%
more = ""
pdAll = []
for i in range(len(df2)):
    title_class = df2["title_class"][i]
    title_id = df2["title_id"][i]
    title = df2["title"][i]
    title_cnt = df2["title_cnt"][i]
    cate_class = df2["cate_class"][i]
    cate_id = df2["cate_id"][i]
    cate = df2["cate"][i]
    cate_cnt = df2["cate_cnt"][i]
    sub_class = df2["sub_class"][i]
    sub_cnt = df2["sub_cnt"][i]
    sub_cate = df2["sub_cate"][i]
    sub_id = df2["sub_id"][i]
    cate_site = df2["site"][i]
    
    search = df2["site"][i]
    driver = webdriver.Firefox()
    driver.get(search)
    sleep(3)
    
    html = driver.page_source
    page = BeautifulSoup(html)
    #print(page)
    
    while True:
        #print(more)
        html = driver.page_source
        page = BeautifulSoup(html)
        more = page.find_all("p", {"class" : "btn_more mt20"})
        more = str(more)
        print(more)

        if "display:none" in more:
            #print("no more")
            break
        else:
            if "display: none" in more:
            #print("no more")
                break

        image = driver.find_element_by_id("btn_more_prod")
        sleep(3)
        image.click()
        #print("click")
        html = driver.page_source
        page = BeautifulSoup(html)
        #print(page)
        sleep(3)
        #print(page)

    #html = driver.page_source
    #page = BeautifulSoup(html)
    #print(page)
    pdList = page.find_all("ul", {"id" : "ul_prod_list"})
    
    for line in pdList:
        pdList = str(line)
    pdList = pdList.replace("><", ">\n<")
    pdList = pdList.split("\n")
    #print(pdList)
    
    pd_id = ""
    pd_img = ""
    pd_ttl = ""
    pd_brand = ""
    detail = []
    #print(pdList)
    for line in pdList:
        #print(line)
        if "<a class=\"btn_detail\"" in line:
            pd_id = str(line)
            pd_id = pd_id[-22: ]
            pd_id = pd_id[:-2]
        if "onerror" in line:
            pd_img = str(line)
            pd_img = pd_img.split(" ")
            #print(pd_img)
            for img in pd_img:
                if "http:" in img:
                    pd_img = img[5:-3]
            detail = [pd_id, pd_img]
        if "<p class=\"brand" in line:
            pd_brand = line
            pd_brand = pd_brand[17:-4]
            #print(pd_brand)
        if "<p class=\"ttl" in line:
            pd_ttl = line
            pd_ttl = pd_ttl[15:-4]
            #print(pd_ttl)
            detail = [pd_ttl, pd_brand, pd_id, pd_img]
            #print(detail)
            category = [title_class, title_id, title, title_cnt, cate_class, cate_id, cate, cate_cnt, sub_class, sub_id, sub_cate, sub_cnt, search, pd_ttl, pd_brand, pd_id, pd_img]
            pdAll.append(category)
    driver.quit()
# Out:
# /Users/SeulA/anaconda/lib/python3.6/site-packages/bs4/__init__.py:181: UserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("lxml"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 193 of the file /Users/SeulA/anaconda/lib/python3.6/runpy.py. To get rid of this warning, change code that looks like this:
#
#  BeautifulSoup([your markup])
#
# to this:
#
#  BeautifulSoup([your markup], "lxml")
#
#   markup_type=markup_type))
# [<p class="btn_more mt20" id="btn_more_prod"><a href="#"><span>더보기</span></a></p>]
# [<p class="btn_more mt20" id="btn_more_prod" style="display: none;"><a href="#"><span>더보기</span></a></p>]
# ...

# %%
pdAll
# Out:
# [['Categorycd1',
#   'CTG001',
#   '스킨케어',
#   '스킨케어',
#   'Categorycd2',
#   'CTG008',
#   '클렌징',
#   '68',
#   'Categorycd3',
#   'CTG009',
#   '메이크업 리무버',
#   '23',
#   'http://www.aritaum.com/shop/pr/shop_pr_product_list.do?i_sCategorycd1=CTG001&i_sCategorycd2=CTG008&i_sCategorycd3=CTG009',
#   '뽀오얀 미소 발효 립 &amp; 아이 리무버',
#   '아리따움',
#   'P0000000000000000768',
#   'http://cdn.aritaum.com/UPLOAD/UPLOAD_IMAGE/PRD_2015/IMG1446wfQ194345704_356.j'],
#  ['Categorycd1',
#   'CTG001',
#   '스킨케어',
#   '스킨케어',
#   'Categorycd2',
#   'CTG008',
#   '클렌징',
#   '68',
#   'Categorycd3',
#   'CTG009',
#   '메이크업 리무버',
#   '23',
#   'http://www.aritaum.com/shop/pr/shop_pr_product_list.do?i_sCategorycd1=CTG001&i_sCategorycd2=CTG008&i_sCategorycd3=CTG009',
#   '알로에 노워시 클렌징 티슈',
#   '아리따움',
#   'P0000000000000007770',
#   'http://cdn.aritaum.com/UPLOAD/UPLOAD_IMAGE/PRD_2015/IMG1446GwP194432202_356.j'],
#  ['Categorycd1',
#   'CTG001',
#   '스킨케어',
#   '스킨케어',
#   'Categorycd2',
#   'CTG008',
# ...

# %%
head = ["title_class", "title_id", "title", "title_cnt", "cate_class", "cate_id", "cate", "cate_cnt", "sub_class", "sub_id", "sub_cate", "sub_cnt", "site", "pd_ttl", "pd_brand", "pd_id", "pd_img"]

# %%
sumDf = pd.DataFrame(pdAll, columns = head)

# %%
sumDf
# Out:
#       title_class title_id        title    title_cnt   cate_class cate_id  \
# 0     Categorycd1   CTG001         스킨케어         스킨케어  Categorycd2  CTG008
# 1     Categorycd1   CTG001         스킨케어         스킨케어  Categorycd2  CTG008
# 2     Categorycd1   CTG001         스킨케어         스킨케어  Categorycd2  CTG008
# 3     Categorycd1   CTG001         스킨케어         스킨케어  Categorycd2  CTG008
# 4     Categorycd1   CTG001         스킨케어         스킨케어  Categorycd2  CTG008
# 5     Categorycd1   CTG001         스킨케어         스킨케어  Categorycd2  CTG008
# 6     Categorycd1   CTG001         스킨케어         스킨케어  Categorycd2  CTG008
# 7     Categorycd1   CTG001         스킨케어         스킨케어  Categorycd2  CTG008
# 8     Categorycd1   CTG001         스킨케어         스킨케어  Categorycd2  CTG008
# 9     Categorycd1   CTG001         스킨케어         스킨케어  Categorycd2  CTG008
# 10    Categorycd1   CTG001         스킨케어         스킨케어  Categorycd2  CTG008
# 11    Categorycd1   CTG001         스킨케어         스킨케어  Categorycd2  CTG008
# ...

# %%
pdAll = []
for i in range(len(sumDf)):
    title_class = sumDf["title_class"][i]
    title_id = sumDf["title_id"][i]
    title = sumDf["title"][i]
    title_cnt = sumDf["title"][i]
    cate_class = sumDf["cate_class"][i]
    cate_id = sumDf["cate_id"][i]
    cate = sumDf["cate"][i]
    cate_cnt = sumDf["cate_cnt"][i]
    sub_class = sumDf["sub_class"][i]
    sub_cnt = sumDf["sub_cnt"][i]
    sub_cate = sumDf["sub_cate"][i]
    sub_id = sumDf["sub_id"][i]
    cate_site = sumDf["site"][i]
    pd_ttl = sumDf["pd_ttl"][i]
    pd_brand = sumDf["pd_brand"][i]
    pd_img = sumDf["pd_img"][i]
    pd_id = sumDf["pd_id"][i]
        
    pd_page = "http://www.aritaum.com/shop/pr/shop_pr_product_view.do?i_sTmType=PC_HIS_BAK&i_sProductcd=" + pd_id

    driver = webdriver.Firefox()
    driver.get(pd_page)
    sleep(3)
    
    html = driver.page_source
    page = BeautifulSoup(html)
    de_page = page.find_all("div", {"class" : "slide cycle-slide cycle-slide-active"})
    
    de_page = str(de_page)
    de_page = de_page.replace("><", ">\n<")
    de_page = de_page.split("\n")
    
    for line in de_page:
        if "src=\"http:" in line:
            de_page = line
            de_page = de_page[-78:]
            de_page = de_page[:-3]
            #print(de_page)
    
    category = [title_class, title_id, title, title_cnt, cate_class, cate_id, cate, cate_cnt, sub_class, sub_id, sub_cate, sub_cnt, search, pd_ttl, pd_brand, pd_id, pd_page, pd_img, de_page,]
    pdAll.append(category)
    driver.quit()
# Out:
# /Users/SeulA/anaconda/lib/python3.6/site-packages/bs4/__init__.py:181: UserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("lxml"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 193 of the file /Users/SeulA/anaconda/lib/python3.6/runpy.py. To get rid of this warning, change code that looks like this:
#
#  BeautifulSoup([your markup])
#
# to this:
#
#  BeautifulSoup([your markup], "lxml")
#
#   markup_type=markup_type))
# ...

# %%
ariName = ["title_class", "title_id", "title", "title_cnt", "cate_class", "cate_id", "cate", "cate_cnt", "sub_class", "sub_id", "sub_cate", "sub_cnt", "cate_link", "pd_name", "pd_brand", "pd_id", "pd_page", "pd_img_small", "pd_img_big"]

# %%
aritaum = pd.DataFrame(pdAll, columns = ariName)

# %%
aritaum
