# %% [markdown]
# # Videos Information [update, description]

# %%
import pandas as pd
from selenium import webdriver
from bs4 import BeautifulSoup
from slacker import Slacker
import time
from datetime import datetime

# %%
slack = Slacker(token)

# %%
videos_df = pd.read_csv("youtuber_videos_info.csv", encoding = "utf-8")
videos_df = videos_df.fillna(0)

# %%
youtube = "https://www.youtube.com"
cnt_videos = len(videos_df)

# %%
cnt_videos
# Out:
# 4080

# %%
def init():
    videos_df["update"] = None
    videos_df["description"] = None

# %%
def get_address(i):
    address = youtube + videos_df["video_id"][i]
    return address

# %%
def get_address_bs(ad):
    open_address = driver.get(ad)
    get_source = driver.page_source
    global address_bs
    address_bs = BeautifulSoup(get_source, "html.parser")
    return address_bs

# %%
def find_upload_date(address_bs):
    upload = address_bs.find_all("div", {"id" : "watch-uploader-info"})
    upload = str(upload)
    upload = upload[63:-16]
    return upload

# %%
def find_description(address_bs):
    global description
    describe = address_bs.find_all("p", {"id" : "eow-description"})
    describe = str(describe)
    describe = describe[34:-5]
    describe = describe.replace("</a>", "")
    describe = describe.replace("<br/>", "\n")
    describe = describe.split("<a class=\"")
    for i in range(len(describe)):
        if "yt-uix-servicelink" in describe[i]:
            result = describe[i]
            result = result.split("target=\"_blank\">")
            describe[i] = result[1]
        if "yt-uix-sessionlink" in describe[i]:
            result = describe[i]
            result = result.split("\">")
            describe[i] = result[1]
    description = "".join(describe)
    return description

# %%
#init()
#videos_df

# %%
#slack.chat.post_message('#crawling', "Start video update and description crawling")

# %%
driver = webdriver.Firefox()
for i in range(cnt_videos):
    print(i)
    if videos_df["update"][i] == 0:
        try:
            while(1):
                slack.chat.post_message('#crawling', i)
                address = get_address(i)
                address_bs = get_address_bs(address)
                upload = find_upload_date(address_bs)
                description = find_description(address_bs)
                videos_df["update"][i] = upload
                videos_df["description"][i] = description
                videos_df.to_csv("youtuber_videos_info.csv", encoding="utf-8", index=False)
                if upload != 0:
                    break
                else:
                    slack.chat.post_message('#finish', str(i)+":0")
        except:
            slack.chat.post_message('#finish', "Error in Video Crawler")
driver.quit()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-91-fd0b1317076b> in <module>()
# ----> 1 driver = webdriver.Firefox()
#       2 for i in range(cnt_videos):
#       3     print(i)
#       4     if videos_df["update"][i] == 0:
#       5         try:
#
# /usr/local/lib/python3.5/dist-packages/selenium/webdriver/firefox/webdriver.py in __init__(self, firefox_profile, firefox_binary, timeout, capabilities, proxy, executable_path, firefox_options, log_path)
#     150                 command_executor=executor,
#     151                 desired_capabilities=capabilities,
# --> 152                 keep_alive=True)
#     153
#     154         # Selenium remote
#
# /usr/local/lib/python3.5/dist-packages/selenium/webdriver/remote/webdriver.py in __init__(self, command_executor, desired_capabilities, browser_profile, proxy, keep_alive, file_detector)
#      96             warnings.warn("Please use FirefoxOptions to set browser profile",
#      97                           DeprecationWarning)
# ---> 98         self.start_session(desired_capabilities, browser_profile)
#      99         self._switch_to = SwitchTo(self)
#     100         self._mobile = Mobile(self)
#
# /usr/local/lib/python3.5/dist-packages/selenium/webdriver/remote/webdriver.py in start_session(self, capabilities, browser_profile)
#     186         parameters = {"capabilities": w3c_caps,
#     187                       "desiredCapabilities": capabilities}
# --> 188         response = self.execute(Command.NEW_SESSION, parameters)
#     189         if 'sessionId' not in response:
#     190             response = response['value']
#
# /usr/local/lib/python3.5/dist-packages/selenium/webdriver/remote/webdriver.py in execute(self, driver_command, params)
#     252
#     253         params = self._wrap_value(params)
# --> 254         response = self.command_executor.execute(driver_command, params)
#     255         if response:
#     256             self.error_handler.check_response(response)
#
# /usr/local/lib/python3.5/dist-packages/selenium/webdriver/remote/remote_connection.py in execute(self, command, params)
#     462         path = string.Template(command_info[1]).substitute(params)
#     463         url = '%s%s' % (self._url, path)
# --> 464         return self._request(command_info[0], url, body=data)
#     465
#     466     def _request(self, method, url, body=None):
#
# /usr/local/lib/python3.5/dist-packages/selenium/webdriver/remote/remote_connection.py in _request(self, method, url, body)
#     486             try:
#     487                 self._conn.request(method, parsed_url.path, body, headers)
# --> 488                 resp = self._conn.getresponse()
#     489             except (httplib.HTTPException, socket.error):
#     490                 self._conn.close()
#
# /usr/lib/python3.5/http/client.py in getresponse(self)
#    1195         try:
#    1196             try:
# -> 1197                 response.begin()
#    1198             except ConnectionError:
#    1199                 self.close()
#
# /usr/lib/python3.5/http/client.py in begin(self)
#     295         # read until we get a non-100 response
#     296         while True:
# --> 297             version, status, reason = self._read_status()
#     298             if status != CONTINUE:
#     299                 break
#
# /usr/lib/python3.5/http/client.py in _read_status(self)
#     256
#     257     def _read_status(self):
# --> 258         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     259         if len(line) > _MAXLINE:
#     260             raise LineTooLong("status line")
#
# /usr/lib/python3.5/socket.py in readinto(self, b)
#     573         while True:
#     574             try:
# --> 575                 return self._sock.recv_into(b)
#     576             except timeout:
#     577                 self._timeout_occurred = True
#
# KeyboardInterrupt:

# %%
slack.chat.post_message('#finish', "Finish video update and description crawling")
# Out:
# ---------------------------------------------------------------------------
# Error                                     Traceback (most recent call last)
# <ipython-input-18-02efe369d4c1> in <module>()
# ----> 1 slack.chat.post_message('#finish', "Finish video update and description crawling")
#
# /usr/local/lib/python3.5/dist-packages/slacker/__init__.py in post_message(self, channel, text, username, as_user, parse, link_names, attachments, unfurl_links, unfurl_media, icon_url, icon_emoji, thread_ts)
#     334                              'icon_url': icon_url,
#     335                              'icon_emoji': icon_emoji,
# --> 336                              'thread_ts': thread_ts
#     337                          })
#     338
#
# /usr/local/lib/python3.5/dist-packages/slacker/__init__.py in post(self, api, **kwargs)
#      94         return self._request(
#      95             self._session_post if self.session else requests.post,
# ---> 96             api, **kwargs
#      97         )
#      98
#
# /usr/local/lib/python3.5/dist-packages/slacker/__init__.py in _request(self, method, api, **kwargs)
#      70         response = Response(response.text)
#      71         if not response.successful:
# ---> 72             raise Error(response.error)
#      73
#      74         return response
#
# Error: invalid_auth

# %% [markdown]
# ## Addition By Mistake

# %%
f = open("../../slack_token.txt")
token = f.readline()[1:-2]
token
slack = Slacker(token)

# %%
start_time = datetime.now()
slack.chat.post_message('#finish', "*Start* " + str(datetime.now()) + "\n" + "> 💣 Remove sessionlink code in description", as_user = True)

# %%
#none_num = 0
#sl_num = 0

# %%
driver = webdriver.Firefox()
for i in range(cnt_videos):
    if videos_df["description"][i] == 0:
        none_num += 1
    elif "yt-uix-sessionlink" in videos_df["description"][i]:
        print(i)
        sl_num += 1
        message = "*number : " + str(i) + "*, http://www.youtube.com" + videos_df["video_id"][i]
        slack.chat.post_message('#crawling', message)
        address = get_address(i)
        address_bs = get_address_bs(address)
        description = find_description(address_bs)
        videos_df["description"][i] = description
        videos_df.to_csv("youtuber_videos_info.csv", encoding="utf-8", index=False)
        slack.chat.post_message('#crawling', "```" + description + "```")
driver.quit()
# Out:
# 991
# 992
# 994
# 995
# 996
# 997
# 998
# 999
# 1001
# 1005
# 1007
# 1008
# 1009
# 1013
# 1015
# 1016
# 1019
# 1036
# 1080
# 1081
# 1083
# 1085
# 1086
# 1087
# 1091
# 1092
# 1101
# 1104
# 1106
# 1110
# 1112
# 1115
# 1116
# 1117
# 1118
# 1119
# 1120
# 1121
# 1122
# 1123
# 1124
# 1125
# 1127
# 1128
# 1129
# 1130
# 1131
# 1132
# 1133
# 1134
# 1135
# 